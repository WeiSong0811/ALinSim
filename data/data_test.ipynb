# %%
import pandas as pd
import numpy as np

df_1 = pd.read_csv('./fea_output_45.csv')
df_2 = pd.read_csv('./fea_output_41.csv')
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
label_col = 'max_uz'
for i in range(5,50,2):
    train_df = df_1.iloc[:i]
    X_train = train_df.drop(columns=[label_col])
    y_train = train_df[label_col]
    X_test = df_2.drop(columns=[label_col])
    y_test = df_2[label_col]

    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    print(f'{i}_R² Score: {r2:.4f}')
# Out:
# 5_R² Score: 0.0345
# 7_R² Score: 0.0377
# 9_R² Score: -0.3913
# 11_R² Score: -0.0614
# 13_R² Score: 0.1785
# 15_R² Score: 0.2696
# 17_R² Score: 0.2800
# 19_R² Score: 0.3294
# 21_R² Score: 0.3562
# 23_R² Score: 0.3941
# 25_R² Score: 0.4370
# 27_R² Score: 0.3341
# 29_R² Score: 0.3241
# 31_R² Score: 0.3366
# 33_R² Score: 0.2144
# 35_R² Score: 0.2312
# 37_R² Score: 0.3886
# 39_R² Score: 0.4015
# 41_R² Score: 0.5227
# 43_R² Score: 0.4638
# 45_R² Score: 0.4584
# 47_R² Score: 0.4877
# 49_R² Score: 0.5081
