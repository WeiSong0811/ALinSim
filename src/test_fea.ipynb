# %%
from fea import run_fea

X = [ 1.0e+02,  2.0e+00,  5.0e+03,  2.4e+04, -5.0e+00, 0.0e+00]
y = run_fea(X)
print(y)
# Out:
# Beginning Analysis
# Complete 4 load case in 16.755 secs
# 19.307432820061006
