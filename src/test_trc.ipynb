# %%
from utils import generation_pool_trc
X_test_trc, X, _ = generation_pool_trc(seed=52, n_test=150, delta_factor=0.5)
# Out:
# Total valid pool combinations (paper-consistent): 21168 (should be 21168)
# Valid pool count (paper-consistent): 21168, should be 21168
# delta = 0.1865  (=0.5 * median NN distance in normalized space)
# Pool after removing test points: 21018
# Pool kept after distance filtering: 18994 / 21018

# %%
X_test_trc.to_csv(f'./run_trc/data/trc_test_seed52.csv', index=False)
