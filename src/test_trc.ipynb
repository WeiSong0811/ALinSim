# %%
from run_trc import predict
from utils import generation_pool_trc
_, X, _ = generation_pool_trc(seed=42)
# Out:
# Total valid pool combinations (paper-consistent): 21168 (should be 21168)
# Valid pool count (paper-consistent): 21168, should be 21168
# delta = 0.1905  (=0.5 * median NN distance in normalized space)
# Pool after removing test points: 21068
# Pool kept after distance filtering: 19744 / 21068

# %%
y = predict(X.loc[1000].values)
